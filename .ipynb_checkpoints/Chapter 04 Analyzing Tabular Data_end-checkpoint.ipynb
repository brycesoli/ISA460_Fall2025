# %% [markdown]
# # Chapter 4 Analyzing tabular data with pyspark
#
# This chapter cover:
#
# - Reading delimited data into a PySpark data frame
# - Understanding how PySpark represents tabular data in a data frame
# - Ingesting and exploring tabular or relational data
# - Selecting, manipulating, renaming, and deleting columns in a data frame
# - Summarizing data frames for quick exploration

# %%
from pyspark.sql import SparkSession
import pyspark.sql.functions as F

# change the account name to your email account
account='sli'

# define a root path to access the data in the DataAnalysisWithPythonAndPySpark
data_path='/net/clusterhn/home/'+account+'/isa460/data/'

spark = (SparkSession.builder.appName("Analyzing tabluar data")
        .config("spark.port.maxRetries", "100")
        .getOrCreate())

# confiture the log level (defaulty is WWARN)
spark.sparkContext.setLogLevel('ERROR')
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/10/02 07:36:18 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 25/10/02 07:36:19 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 25/10/02 07:36:19 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.
# 25/10/02 07:36:19 WARN Utils: Service 'SparkUI' could not bind on port 4042. Attempting port 4043.
# 25/10/02 07:36:19 WARN Utils: Service 'SparkUI' could not bind on port 4043. Attempting port 4044.
# 25/10/02 07:36:19 WARN Utils: Service 'SparkUI' could not bind on port 4044. Attempting port 4045.
# 25/10/02 07:36:19 WARN Utils: Service 'SparkUI' could not bind on port 4045. Attempting port 4046.
# 25/10/02 07:36:19 WARN Utils: Service 'SparkUI' could not bind on port 4046. Attempting port 4047.
# 25/10/02 07:36:19 WARN Utils: Service 'SparkUI' could not bind on port 4047. Attempting port 4048.
# 25/10/02 07:36:19 WARN Utils: Service 'SparkUI' could not bind on port 4048. Attempting port 4049.
# 25/10/02 07:36:19 WARN Utils: Service 'SparkUI' could not bind on port 4049. Attempting port 4050.
# 25/10/02 07:36:19 WARN Utils: Service 'SparkUI' could not bind on port 4050. Attempting port 4051.
# 25/10/02 07:36:19 WARN Utils: Service 'SparkUI' could not bind on port 4051. Attempting port 4052.
# 25/10/02 07:36:19 WARN Utils: Service 'SparkUI' could not bind on port 4052. Attempting port 4053.
# 25/10/02 07:36:19 WARN Utils: Service 'SparkUI' could not bind on port 4053. Attempting port 4054.
# 25/10/02 07:36:19 WARN Utils: Service 'SparkUI' could not bind on port 4054. Attempting port 4055.
# 25/10/02 07:36:19 WARN Utils: Service 'SparkUI' could not bind on port 4055. Attempting port 4056.
# 25/10/02 07:36:19 WARN Utils: Service 'SparkUI' could not bind on port 4056. Attempting port 4057.

# %%
# import data from a list of lists

my_grocery_list=[
    ["Banana", 2, 1.74],
    ["Apple", 4, 2.04],
    ["Carrot", 1, 1.09],
    ["cake", 1, 10.99]
]

# create a Dataframe based on the list

df=spark.createDataFrame(my_grocery_list, ["Item", "Quantity", "Price"])

df.printSchema()
# Out:
# root
#  |-- Item: string (nullable = true)
#  |-- Quantity: long (nullable = true)
#  |-- Price: double (nullable = true)

# %% [markdown]
# ## import data from a csv file
#
# For this exercise, we’ll use some open data from the government of Canada, more specifically the CRTC (Canadian Radio-Television and Telecommunications Commission). Every broadcaster is mandated to provide a complete log of the programs and commercials showcased to the Canadian public. This gives us a lot of potential questions to answer, but we’ll select just one:
# **What are the channels with the greatest and least proportion of commercials?**
#
# You can download the [file](http://mng.bz/y4YJ) on the Canada Open Data portal ; select the BroadcastLogs_2018_Q3_M8 file. The file is 994 MB to download, which might be too large, depending on your computer. The book’s repository contains a sample of the data under the data/broadcast_logs directory, which you can use in place of the original file. You also need to download the Data Dictionary in .doc form, as well as the Reference Tables zip file, unzipping them into a ReferenceTables directory in data/ broadcast_logs. Once again, the examples assume that the data is downloaded under data/broadcast_logs and that PySpark is launched from the root of the repository.

# %%
import os

directory=data_path+'/broadcast_logs/'

logs=spark.read.csv(os.path.join(directory, "BroadcastLogs_2018_Q3_M8_sample.CSV"),
                                 sep="|",
                                 header=True,
                                 inferSchema=True,
                                 timestampFormat="yyyy-MM-dd",)

# %%
logs.printSchema()
# Out:
# root
#  |-- BroadcastLogID: integer (nullable = true)
#  |-- LogServiceID: integer (nullable = true)
#  |-- LogDate: date (nullable = true)
#  |-- SequenceNO: integer (nullable = true)
#  |-- AudienceTargetAgeID: integer (nullable = true)
#  |-- AudienceTargetEthnicID: integer (nullable = true)
#  |-- CategoryID: integer (nullable = true)
#  |-- ClosedCaptionID: integer (nullable = true)
#  |-- CountryOfOriginID: integer (nullable = true)
#  |-- DubDramaCreditID: integer (nullable = true)
#  |-- EthnicProgramID: integer (nullable = true)
#  |-- ProductionSourceID: integer (nullable = true)
#  |-- ProgramClassID: integer (nullable = true)
#  |-- FilmClassificationID: integer (nullable = true)
#  |-- ExhibitionID: integer (nullable = true)
#  |-- Duration: string (nullable = true)
#  |-- EndTime: string (nullable = true)
#  |-- LogEntryDate: date (nullable = true)
#  |-- ProductionNO: string (nullable = true)
#  |-- ProgramTitle: string (nullable = true)
#  |-- StartTime: string (nullable = true)
#  |-- Subtitle: string (nullable = true)
#  |-- NetworkAffiliationID: integer (nullable = true)
#  |-- SpecialAttentionID: integer (nullable = true)
#  |-- BroadcastOriginPointID: integer (nullable = true)
#  |-- CompositionID: integer (nullable = true)
#  |-- Producer1: string (nullable = true)
#  |-- Producer2: string (nullable = true)
#  |-- Language1: integer (nullable = true)
#  |-- Language2: integer (nullable = true)

# %% [markdown]
# ## Exploring the shape of our data universe
#
# ![Figure 4.4](https://raw.githubusercontent.com/Suhong88/ISA460_Fall2023/main/images/Figure%204.4.png)

# %% [markdown]
# ## The basics of data manipulation: Selecting, dropping, renaming, ordering, diagnosing

# %% [markdown]
# ### Select columns

# %%
logs.select("BroadcastLogID", "LogServiceID", "LogDate").show(5, False)
# Out:
# +--------------+------------+----------+
# |BroadcastLogID|LogServiceID|LogDate   |
# +--------------+------------+----------+
# |1196192316    |3157        |2018-08-01|
# |1196192317    |3157        |2018-08-01|
# |1196192318    |3157        |2018-08-01|
# |1196192319    |3157        |2018-08-01|
# |1196192320    |3157        |2018-08-01|
# +--------------+------------+----------+
# only showing top 5 rows

# %%
# four ways of selecting columns
# Using the string to column conversion
logs.select("BroadCastLogID", "LogServiceID", "LogDate")

# use * to unpack a list
logs.select(*["BroadCastLogID", "LogServiceID", "LogDate"])
 
# Passing the column object explicitly
logs.select(
    F.col("BroadCastLogID"), F.col("LogServiceID"), F.col("LogDate")
)
logs.select(
    *[F.col("BroadCastLogID"), F.col("LogServiceID"), F.col("LogDate")]
)
# Out:
# DataFrame[BroadCastLogID: int, LogServiceID: int, LogDate: date]

# %%
# for a dataframe with a lot of columns, we can slice the columns into groups to display them by small groups

total_columns=len(logs.columns)

columns_per_row=5

for i in range(0, total_columns, columns_per_row):
    logs.select(logs.columns[i:i+columns_per_row]).show(5)

# %%
def displayByGroup(df, columns_per_row=5, num_of_row=5):
    total_columns=len(df.columns)
    for i in range(0, total_columns, columns_per_row):
       df.select(df.columns[i:i+columns_per_row]).show(num_of_row)

# %%
displayByGroup(logs, 6,10)

# %%
# for a dataframe with a lot of columns, we can slice the columns into groups to display them by small groups

import numpy as np

total_columns=len(logs.columns)

columns_per_row=5

group_size=total_columns//columns_per_row

column_split=np.array_split(logs.columns, group_size)

for columns in column_split:
    logs.select(*columns).show(5)
# Out:
# +--------------+------------+----------+----------+-------------------+
# |BroadcastLogID|LogServiceID|   LogDate|SequenceNO|AudienceTargetAgeID|
# +--------------+------------+----------+----------+-------------------+
# |    1196192316|        3157|2018-08-01|         1|                  4|
# |    1196192317|        3157|2018-08-01|         2|               NULL|
# |    1196192318|        3157|2018-08-01|         3|               NULL|
# |    1196192319|        3157|2018-08-01|         4|               NULL|
# |    1196192320|        3157|2018-08-01|         5|               NULL|
# +--------------+------------+----------+----------+-------------------+
# only showing top 5 rows
#
# +----------------------+----------+---------------+-----------------+----------------+
# |AudienceTargetEthnicID|CategoryID|ClosedCaptionID|CountryOfOriginID|DubDramaCreditID|
# +----------------------+----------+---------------+-----------------+----------------+
# |                  NULL|        13|              3|                3|            NULL|
# |                  NULL|      NULL|              1|             NULL|            NULL|
# |                  NULL|      NULL|              1|             NULL|            NULL|
# |                  NULL|      NULL|              1|             NULL|            NULL|
# |                  NULL|      NULL|              1|             NULL|            NULL|
# +----------------------+----------+---------------+-----------------+----------------+
# only showing top 5 rows
#
# +---------------+------------------+--------------+--------------------+------------+
# |EthnicProgramID|ProductionSourceID|ProgramClassID|FilmClassificationID|ExhibitionID|
# +---------------+------------------+--------------+--------------------+------------+
# |           NULL|                10|            19|                NULL|           2|
# |           NULL|              NULL|            20|                NULL|        NULL|
# |           NULL|              NULL|             3|                NULL|        NULL|
# |           NULL|              NULL|             3|                NULL|        NULL|
# |           NULL|              NULL|             3|                NULL|        NULL|
# +---------------+------------------+--------------+--------------------+------------+
# only showing top 5 rows
#
# +----------------+----------------+------------+------------+--------------------+
# |        Duration|         EndTime|LogEntryDate|ProductionNO|        ProgramTitle|
# +----------------+----------------+------------+------------+--------------------+
# |02:00:00.0000000|08:00:00.0000000|  2018-08-01|      A39082|   Newlywed and Dead|
# |00:00:30.0000000|06:13:45.0000000|  2018-08-01|        NULL|15-SPECIALTY CHAN...|
# |00:00:15.0000000|06:14:00.0000000|  2018-08-01|        NULL|3-PROCTER & GAMBL...|
# |00:00:15.0000000|06:14:15.0000000|  2018-08-01|        NULL|12-CREDIT KARMA-B...|
# |00:00:15.0000000|06:14:30.0000000|  2018-08-01|        NULL|3-L'OREAL CANADA-...|
# +----------------+----------------+------------+------------+--------------------+
# only showing top 5 rows
#
# +----------------+--------+--------------------+------------------+----------------------+
# |       StartTime|Subtitle|NetworkAffiliationID|SpecialAttentionID|BroadcastOriginPointID|
# +----------------+--------+--------------------+------------------+----------------------+
# |06:00:00.0000000|    NULL|                NULL|              NULL|                  NULL|
# |06:13:15.0000000|    NULL|                NULL|              NULL|                  NULL|
# |06:13:45.0000000|    NULL|                NULL|              NULL|                  NULL|
# |06:14:00.0000000|    NULL|                NULL|              NULL|                  NULL|
# |06:14:15.0000000|    NULL|                NULL|              NULL|                  NULL|
# +----------------+--------+--------------------+------------------+----------------------+
# only showing top 5 rows
#
# +-------------+---------+---------+---------+---------+
# |CompositionID|Producer1|Producer2|Language1|Language2|
# +-------------+---------+---------+---------+---------+
# |         NULL|     NULL|     NULL|       94|     NULL|
# |         NULL|     NULL|     NULL|     NULL|     NULL|
# |         NULL|     NULL|     NULL|     NULL|     NULL|
# |         NULL|     NULL|     NULL|     NULL|     NULL|
# |         NULL|     NULL|     NULL|     NULL|     NULL|
# +-------------+---------+---------+---------+---------+
# only showing top 5 rows

# %%
# create a function to display sample records by a group of columns

import numpy as np

def displayColumnsByGroup (df, columns_per_row, sample_size=5):
    
    total_columns=len(df.columns)
    group_size=total_columns//columns_per_row

    column_split=np.array_split(df.columns, group_size)

    for columns in column_split:
        df.select(*columns).show(sample_size)

# %%
# display logs file by five columns per row

displayColumnsByGroup(logs, 5)
# displayColumnsByGroup(logs, 5, 10)
# Out:
# +--------------+------------+----------+----------+-------------------+
# |BroadcastLogID|LogServiceID|   LogDate|SequenceNO|AudienceTargetAgeID|
# +--------------+------------+----------+----------+-------------------+
# |    1196192316|        3157|2018-08-01|         1|                  4|
# |    1196192317|        3157|2018-08-01|         2|               NULL|
# |    1196192318|        3157|2018-08-01|         3|               NULL|
# |    1196192319|        3157|2018-08-01|         4|               NULL|
# |    1196192320|        3157|2018-08-01|         5|               NULL|
# +--------------+------------+----------+----------+-------------------+
# only showing top 5 rows
#
# +----------------------+----------+---------------+-----------------+----------------+
# |AudienceTargetEthnicID|CategoryID|ClosedCaptionID|CountryOfOriginID|DubDramaCreditID|
# +----------------------+----------+---------------+-----------------+----------------+
# |                  NULL|        13|              3|                3|            NULL|
# |                  NULL|      NULL|              1|             NULL|            NULL|
# |                  NULL|      NULL|              1|             NULL|            NULL|
# |                  NULL|      NULL|              1|             NULL|            NULL|
# |                  NULL|      NULL|              1|             NULL|            NULL|
# +----------------------+----------+---------------+-----------------+----------------+
# only showing top 5 rows
#
# +---------------+------------------+--------------+--------------------+------------+
# |EthnicProgramID|ProductionSourceID|ProgramClassID|FilmClassificationID|ExhibitionID|
# +---------------+------------------+--------------+--------------------+------------+
# |           NULL|                10|            19|                NULL|           2|
# |           NULL|              NULL|            20|                NULL|        NULL|
# |           NULL|              NULL|             3|                NULL|        NULL|
# |           NULL|              NULL|             3|                NULL|        NULL|
# |           NULL|              NULL|             3|                NULL|        NULL|
# +---------------+------------------+--------------+--------------------+------------+
# only showing top 5 rows
#
# +----------------+----------------+------------+------------+--------------------+
# |        Duration|         EndTime|LogEntryDate|ProductionNO|        ProgramTitle|
# +----------------+----------------+------------+------------+--------------------+
# |02:00:00.0000000|08:00:00.0000000|  2018-08-01|      A39082|   Newlywed and Dead|
# |00:00:30.0000000|06:13:45.0000000|  2018-08-01|        NULL|15-SPECIALTY CHAN...|
# |00:00:15.0000000|06:14:00.0000000|  2018-08-01|        NULL|3-PROCTER & GAMBL...|
# |00:00:15.0000000|06:14:15.0000000|  2018-08-01|        NULL|12-CREDIT KARMA-B...|
# |00:00:15.0000000|06:14:30.0000000|  2018-08-01|        NULL|3-L'OREAL CANADA-...|
# +----------------+----------------+------------+------------+--------------------+
# only showing top 5 rows
#
# +----------------+--------+--------------------+------------------+----------------------+
# |       StartTime|Subtitle|NetworkAffiliationID|SpecialAttentionID|BroadcastOriginPointID|
# +----------------+--------+--------------------+------------------+----------------------+
# |06:00:00.0000000|    NULL|                NULL|              NULL|                  NULL|
# |06:13:15.0000000|    NULL|                NULL|              NULL|                  NULL|
# |06:13:45.0000000|    NULL|                NULL|              NULL|                  NULL|
# |06:14:00.0000000|    NULL|                NULL|              NULL|                  NULL|
# |06:14:15.0000000|    NULL|                NULL|              NULL|                  NULL|
# +----------------+--------+--------------------+------------------+----------------------+
# only showing top 5 rows
#
# +-------------+---------+---------+---------+---------+
# |CompositionID|Producer1|Producer2|Language1|Language2|
# +-------------+---------+---------+---------+---------+
# |         NULL|     NULL|     NULL|       94|     NULL|
# |         NULL|     NULL|     NULL|     NULL|     NULL|
# |         NULL|     NULL|     NULL|     NULL|     NULL|
# |         NULL|     NULL|     NULL|     NULL|     NULL|
# |         NULL|     NULL|     NULL|     NULL|     NULL|
# +-------------+---------+---------+---------+---------+
# only showing top 5 rows

# %% [markdown]
# ### store this function into a python file to be used later

# %% [markdown]
# ### Drop columns

# %%
logs1 = logs.drop("BroadcastLogID", "SequenceNO")

# Testing if we effectively got rid of the columns
 
print("BroadcastLogID" in logs1.columns)  # => False
print("SequenceNO" in logs1.columns)  # => False
# Out:
# False
# False

# %%
# instead drop, you can also select the ones you want to keep
logs1 = logs.select(
    *[c for c in logs.columns if c not in ["BroadcastLogID", "SequenceNO"]]
)

logs1.columns
# Out:
# ['LogServiceID',
#  'LogDate',
#  'AudienceTargetAgeID',
#  'AudienceTargetEthnicID',
#  'CategoryID',
#  'ClosedCaptionID',
#  'CountryOfOriginID',
#  'DubDramaCreditID',
#  'EthnicProgramID',
#  'ProductionSourceID',
#  'ProgramClassID',
#  'FilmClassificationID',
#  'ExhibitionID',
#  'Duration',
#  'EndTime',
#  'LogEntryDate',
#  'ProductionNO',
#  'ProgramTitle',
#  'StartTime',
#  'Subtitle',
#  'NetworkAffiliationID',
#  'SpecialAttentionID',
#  'BroadcastOriginPointID',
#  'CompositionID',
#  'Producer1',
#  'Producer2',
#  'Language1',
#  'Language2']

# %% [markdown]
# ### Create new columns

# %%
# create a column showing duration in seconds

logs.select("Duration").show(5)
# Out:
# +----------------+
# |        Duration|
# +----------------+
# |02:00:00.0000000|
# |00:00:30.0000000|
# |00:00:15.0000000|
# |00:00:15.0000000|
# |00:00:15.0000000|
# +----------------+
# only showing top 5 rows

# %%
logs.select(F.col("Duration")).dtypes
# Out:
# [('Duration', 'string')]

# %%
# step 1: extract hours, minutes and seconds

logs.select(F.col("Duration").substr(1,2).cast("int").alias("dur_hours"), 
            F.col("Duration").substr(4,2).cast("int").alias("dur_minutes"),
            F.col("Duration").substr(7,2).cast("int").alias("dur_seconds")).show()
# Out:
# +---------+-----------+-----------+
# |dur_hours|dur_minutes|dur_seconds|
# +---------+-----------+-----------+
# |        2|          0|          0|
# |        0|          0|         30|
# |        0|          0|         15|
# |        0|          0|         15|
# |        0|          0|         15|
# |        0|          0|         15|
# |        0|          0|         30|
# |        0|          0|         15|
# |        0|          0|         15|
# |        0|          0|         15|
# |        0|          0|         15|
# |        0|          0|         30|
# |        0|          0|         30|
# |        0|          0|         15|
# |        0|          0|         15|
# |        0|          0|         15|
# |        0|          0|         15|
# |        0|          0|         15|
# |        0|          1|          0|
# |        0|          0|         15|
# +---------+-----------+-----------+
# only showing top 20 rows

# %%
# step 2. merge all fields into one

logs.select(F.col("Duration"), (F.col("Duration").substr(1,2).cast("int").alias("dur_hours")*60*60+ 
            F.col("Duration").substr(4,2).cast("int").alias("dur_minutes")*60+
            F.col("Duration").substr(7,2).cast("int").alias("dur_seconds")).alias("Duration_seconds")).show(5)
# Out:
# +----------------+----------------+
# |        Duration|Duration_seconds|
# +----------------+----------------+
# |02:00:00.0000000|            7200|
# |00:00:30.0000000|              30|
# |00:00:15.0000000|              15|
# |00:00:15.0000000|              15|
# |00:00:15.0000000|              15|
# +----------------+----------------+
# only showing top 5 rows

# %%
# create a new column for duration in seconds

logs.withColumn("Duration_seconds", F.col("Duration").substr(1,2).cast("int").alias("dur_hours")*60*60+ 
            F.col("Duration").substr(4,2).cast("int").alias("dur_minutes")*60+
            F.col("Duration").substr(7,2).cast("int").alias("dur_seconds")).select("Duration", "Duration_seconds").show(5)
# Out:
# +----------------+----------------+
# |        Duration|Duration_seconds|
# +----------------+----------------+
# |02:00:00.0000000|            7200|
# |00:00:30.0000000|              30|
# |00:00:15.0000000|              15|
# |00:00:15.0000000|              15|
# |00:00:15.0000000|              15|
# +----------------+----------------+
# only showing top 5 rows

# %%
# print Schema. Why I do not see the new column?
logs.printSchema()
# Out:
# root
#  |-- BroadcastLogID: integer (nullable = true)
#  |-- LogServiceID: integer (nullable = true)
#  |-- LogDate: date (nullable = true)
#  |-- SequenceNO: integer (nullable = true)
#  |-- AudienceTargetAgeID: integer (nullable = true)
#  |-- AudienceTargetEthnicID: integer (nullable = true)
#  |-- CategoryID: integer (nullable = true)
#  |-- ClosedCaptionID: integer (nullable = true)
#  |-- CountryOfOriginID: integer (nullable = true)
#  |-- DubDramaCreditID: integer (nullable = true)
#  |-- EthnicProgramID: integer (nullable = true)
#  |-- ProductionSourceID: integer (nullable = true)
#  |-- ProgramClassID: integer (nullable = true)
#  |-- FilmClassificationID: integer (nullable = true)
#  |-- ExhibitionID: integer (nullable = true)
#  |-- Duration: string (nullable = true)
#  |-- EndTime: string (nullable = true)
#  |-- LogEntryDate: date (nullable = true)
#  |-- ProductionNO: string (nullable = true)
#  |-- ProgramTitle: string (nullable = true)
#  |-- StartTime: string (nullable = true)
#  |-- Subtitle: string (nullable = true)
#  |-- NetworkAffiliationID: integer (nullable = true)
#  |-- SpecialAttentionID: integer (nullable = true)
#  |-- BroadcastOriginPointID: integer (nullable = true)
#  |-- CompositionID: integer (nullable = true)
#  |-- Producer1: string (nullable = true)
#  |-- Producer2: string (nullable = true)
#  |-- Language1: integer (nullable = true)
#  |-- Language2: integer (nullable = true)

# %%
logs1=logs.withColumn("Duration_seconds", F.col("Duration").substr(1,2).cast("int").alias("dur_hours")*60*60+ 
            F.col("Duration").substr(4,2).cast("int").alias("dur_minutes")*60+
            F.col("Duration").substr(7,2).cast("int").alias("dur_seconds"))

# %% [markdown]
# ![Warning](https://raw.githubusercontent.com/Suhong88/ISA460_Fall2023/main/images/Figure%204.5.png)

# %% [markdown]
# ### Rename and Reordering columns

# %%
logs2=logs1.withColumnRenamed("Duration_seconds", "duration_seconds")
logs2.columns
# Out:
# ['BroadcastLogID',
#  'LogServiceID',
#  'LogDate',
#  'SequenceNO',
#  'AudienceTargetAgeID',
#  'AudienceTargetEthnicID',
#  'CategoryID',
#  'ClosedCaptionID',
#  'CountryOfOriginID',
#  'DubDramaCreditID',
#  'EthnicProgramID',
#  'ProductionSourceID',
#  'ProgramClassID',
#  'FilmClassificationID',
#  'ExhibitionID',
#  'Duration',
#  'EndTime',
#  'LogEntryDate',
#  'ProductionNO',
#  'ProgramTitle',
#  'StartTime',
#  'Subtitle',
#  'NetworkAffiliationID',
#  'SpecialAttentionID',
#  'BroadcastOriginPointID',
#  'CompositionID',
#  'Producer1',
#  'Producer2',
#  'Language1',
#  'Language2',
#  'duration_seconds']

# %%
# change all columns to lower case

logs=logs.toDF(*[x.lower() for x in logs.columns])

# %%
# create a function to change all column names to lower caose

def columnLowerCase(df):
    return df.toDF(*[x.lower() for x in df.columns])

# add this function our helper functions

# %%
logs.columns
# Out:
# ['broadcastlogid',
#  'logserviceid',
#  'logdate',
#  'sequenceno',
#  'audiencetargetageid',
#  'audiencetargetethnicid',
#  'categoryid',
#  'closedcaptionid',
#  'countryoforiginid',
#  'dubdramacreditid',
#  'ethnicprogramid',
#  'productionsourceid',
#  'programclassid',
#  'filmclassificationid',
#  'exhibitionid',
#  'duration',
#  'endtime',
#  'logentrydate',
#  'productionno',
#  'programtitle',
#  'starttime',
#  'subtitle',
#  'networkaffiliationid',
#  'specialattentionid',
#  'broadcastoriginpointid',
#  'compositionid',
#  'producer1',
#  'producer2',
#  'language1',
#  'language2']

# %%
#columnLowerCase(logs)

# %%
# order all columns in alphabetical order

logs.select(sorted(logs.columns)).printSchema()

# store the result into a new dataframe

#logs1=logs.select(sorted(logs.columns))
# Out:
# root
#  |-- AudienceTargetAgeID: integer (nullable = true)
#  |-- AudienceTargetEthnicID: integer (nullable = true)
#  |-- BroadcastLogID: integer (nullable = true)
#  |-- BroadcastOriginPointID: integer (nullable = true)
#  |-- CategoryID: integer (nullable = true)
#  |-- ClosedCaptionID: integer (nullable = true)
#  |-- CompositionID: integer (nullable = true)
#  |-- CountryOfOriginID: integer (nullable = true)
#  |-- DubDramaCreditID: integer (nullable = true)
#  |-- Duration: string (nullable = true)
#  |-- EndTime: string (nullable = true)
#  |-- EthnicProgramID: integer (nullable = true)
#  |-- ExhibitionID: integer (nullable = true)
#  |-- FilmClassificationID: integer (nullable = true)
#  |-- Language1: integer (nullable = true)
#  |-- Language2: integer (nullable = true)
#  |-- LogDate: date (nullable = true)
#  |-- LogEntryDate: date (nullable = true)
#  |-- LogServiceID: integer (nullable = true)
#  |-- NetworkAffiliationID: integer (nullable = true)
#  |-- Producer1: string (nullable = true)
#  |-- Producer2: string (nullable = true)
#  |-- ProductionNO: string (nullable = true)
#  |-- ProductionSourceID: integer (nullable = true)
#  |-- ProgramClassID: integer (nullable = true)
#  |-- ProgramTitle: string (nullable = true)
#  |-- SequenceNO: integer (nullable = true)
#  |-- SpecialAttentionID: integer (nullable = true)
#  |-- StartTime: string (nullable = true)
#  |-- Subtitle: string (nullable = true)

# %% [markdown]
# ### Diagnosing a data frame with describe() and summary()

# %%
logs.describe().show()
# Out:
# [Stage 2:======>                                                    (1 + 8) / 9]
# +-------+--------------------+------------------+-----------------+-------------------+----------------------+------------------+-------------------+------------------+------------------+-----------------+------------------+-----------------+--------------------+------------------+----------------+----------------+------------------+------------------+----------------+--------------------+--------------------+------------------+----------------------+------------------+---------+---------+------------------+------------------+
# |summary|      BroadcastLogID|      LogServiceID|       SequenceNO|AudienceTargetAgeID|AudienceTargetEthnicID|        CategoryID|    ClosedCaptionID| CountryOfOriginID|  DubDramaCreditID|  EthnicProgramID|ProductionSourceID|   ProgramClassID|FilmClassificationID|      ExhibitionID|        Duration|         EndTime|      ProductionNO|      ProgramTitle|       StartTime|            Subtitle|NetworkAffiliationID|SpecialAttentionID|BroadcastOriginPointID|     CompositionID|Producer1|Producer2|         Language1|         Language2|
# +-------+--------------------+------------------+-----------------+-------------------+----------------------+------------------+-------------------+------------------+------------------+-----------------+------------------+-----------------+--------------------+------------------+----------------+----------------+------------------+------------------+----------------+--------------------+--------------------+------------------+----------------------+------------------+---------+---------+------------------+------------------+
# |  count|              238945|            238945|           238945|              16112|                  1710|             25506|             224117|             17822|               263|             1895|             16223|           238945|                1885|              9263|          236724|          169979|              3519|            238703|          238945|               15468|              108807|              2395|                  9978|              9978|     2607|       38|             12586|              2629|
# |   mean|1.2168651122760174E9| 3450.890284375065|466.3855824562138| 3.4929245283018866|    120.56432748538012|18.485297577040697| 1.0316174141185184|  4.06390977443609|5.1254752851711025|4.316622691292876|11.193737286568453| 8.49341061750612|   1.953315649867374|  4.52067364784627|            NULL|            NULL| 35710.61538461538|            1999.0|            NULL|   3463.573913043478|   6.082200593711802| 1.704384133611691|    2.1390058127881337|3.4141110442974543|     NULL|     NULL|101.75377403464167|175.49334347660707|
# | stddev|1.4969134241431728E7|199.50673962554765|311.5109104839786| 1.0415963394745125|      71.9869405943613|  9.65585225202084|0.24947032900378968|2.6159675821007333| 3.451329711438564|2.296642145680029| 6.079022239331342|7.902116846905775|  1.6420515263133837|1.4418772626833438|            NULL|            NULL|3749.1340008607654|              NULL|            NULL|  16251.272419144227|   2.990848675228532| 0.539463503486969|    0.9323192037553322|0.9338603403654625|     NULL|     NULL| 45.68403685468215|  86.0360379288395|
# |    min|          1195788151|              3157|                1|                  1|                     4|                 1|                  1|                 2|                 1|                1|                 1|                3|                   1|                 1|00:00:01.0000000|00:00:00.0000000|            030641|  !NO 5PM A ID(:5)|00:00:00.0000000|                #001|                   1|                 1|                     1|                 1|      AMI|    NEWSW|                94|                 3|
# |    max|          1249431576|              3925|             1463|                  4|                   337|                29|                  3|                11|                10|                6|                19|               30|                   8|                 8|06:30:09.0000000|23:59:59.0000000|            c34183|�t� avec Jo�l 2/Un|23:59:59.0000000|�tre dans le trou...|                   9|                 3|                     3|                 4|   VISION|       QC|               437|               438|
# +-------+--------------------+------------------+-----------------+-------------------+----------------------+------------------+-------------------+------------------+------------------+-----------------+------------------+-----------------+--------------------+------------------+----------------+----------------+------------------+------------------+----------------+--------------------+--------------------+------------------+----------------------+------------------+---------+---------+------------------+------------------+

# %%
# for a dataframe with a lot of column, we can describe it one by one

for i in logs.columns:
    logs.select(i).describe().show()

# %%
# return numerical columns

numColumns=[item for item, type in logs.dtypes if type=='int']

numColumns
# Out:
# ['BroadcastLogID',
#  'LogServiceID',
#  'SequenceNO',
#  'AudienceTargetAgeID',
#  'AudienceTargetEthnicID',
#  'CategoryID',
#  'ClosedCaptionID',
#  'CountryOfOriginID',
#  'DubDramaCreditID',
#  'EthnicProgramID',
#  'ProductionSourceID',
#  'ProgramClassID',
#  'FilmClassificationID',
#  'ExhibitionID',
#  'NetworkAffiliationID',
#  'SpecialAttentionID',
#  'BroadcastOriginPointID',
#  'CompositionID',
#  'Language1',
#  'Language2']

# %%
# apply describe to numerical columns
for i in numColumns:
   logs.select(i).describe().show()
# Out:
# +-------+--------------------+
# |summary|      BroadcastLogID|
# +-------+--------------------+
# |  count|              238945|
# |   mean|1.2168651122760174E9|
# | stddev|1.4969134241431728E7|
# |    min|          1195788151|
# |    max|          1249431576|
# +-------+--------------------+
#
# +-------+------------------+
# |summary|      LogServiceID|
# +-------+------------------+
# |  count|            238945|
# |   mean| 3450.890284375065|
# | stddev|199.50673962554765|
# |    min|              3157|
# |    max|              3925|
# +-------+------------------+
#
# +-------+-----------------+
# |summary|       SequenceNO|
# +-------+-----------------+
# |  count|           238945|
# |   mean|466.3855824562138|
# | stddev|311.5109104839786|
# |    min|                1|
# |    max|             1463|
# +-------+-----------------+
#
# +-------+-------------------+
# |summary|AudienceTargetAgeID|
# +-------+-------------------+
# |  count|              16112|
# |   mean| 3.4929245283018866|
# | stddev| 1.0415963394745125|
# |    min|                  1|
# |    max|                  4|
# +-------+-------------------+
#
# +-------+----------------------+
# |summary|AudienceTargetEthnicID|
# +-------+----------------------+
# |  count|                  1710|
# |   mean|    120.56432748538012|
# | stddev|      71.9869405943613|
# |    min|                     4|
# |    max|                   337|
# +-------+----------------------+
#
# +-------+------------------+
# |summary|        CategoryID|
# +-------+------------------+
# |  count|             25506|
# |   mean|18.485297577040697|
# | stddev|  9.65585225202084|
# |    min|                 1|
# |    max|                29|
# +-------+------------------+
#
# +-------+-------------------+
# |summary|    ClosedCaptionID|
# +-------+-------------------+
# |  count|             224117|
# |   mean| 1.0316174141185184|
# | stddev|0.24947032900378968|
# |    min|                  1|
# |    max|                  3|
# +-------+-------------------+
#
# +-------+------------------+
# |summary| CountryOfOriginID|
# +-------+------------------+
# |  count|             17822|
# |   mean|  4.06390977443609|
# | stddev|2.6159675821007333|
# |    min|                 2|
# |    max|                11|
# +-------+------------------+
#
# +-------+------------------+
# |summary|  DubDramaCreditID|
# +-------+------------------+
# |  count|               263|
# |   mean|5.1254752851711025|
# | stddev| 3.451329711438564|
# |    min|                 1|
# |    max|                10|
# +-------+------------------+
#
# +-------+-----------------+
# |summary|  EthnicProgramID|
# +-------+-----------------+
# |  count|             1895|
# |   mean|4.316622691292876|
# | stddev|2.296642145680029|
# |    min|                1|
# |    max|                6|
# +-------+-----------------+
#
# +-------+------------------+
# |summary|ProductionSourceID|
# +-------+------------------+
# |  count|             16223|
# |   mean|11.193737286568453|
# | stddev| 6.079022239331342|
# |    min|                 1|
# |    max|                19|
# +-------+------------------+
#
# +-------+-----------------+
# |summary|   ProgramClassID|
# +-------+-----------------+
# |  count|           238945|
# |   mean| 8.49341061750612|
# | stddev|7.902116846905775|
# |    min|                3|
# |    max|               30|
# +-------+-----------------+
#
# +-------+--------------------+
# |summary|FilmClassificationID|
# +-------+--------------------+
# |  count|                1885|
# |   mean|   1.953315649867374|
# | stddev|  1.6420515263133837|
# |    min|                   1|
# |    max|                   8|
# +-------+--------------------+
#
# +-------+------------------+
# |summary|      ExhibitionID|
# +-------+------------------+
# |  count|              9263|
# |   mean|  4.52067364784627|
# | stddev|1.4418772626833438|
# |    min|                 1|
# |    max|                 8|
# +-------+------------------+
#
# +-------+--------------------+
# |summary|NetworkAffiliationID|
# +-------+--------------------+
# |  count|              108807|
# |   mean|   6.082200593711802|
# | stddev|   2.990848675228532|
# |    min|                   1|
# |    max|                   9|
# +-------+--------------------+
#
# +-------+------------------+
# |summary|SpecialAttentionID|
# +-------+------------------+
# |  count|              2395|
# |   mean| 1.704384133611691|
# | stddev| 0.539463503486969|
# |    min|                 1|
# |    max|                 3|
# +-------+------------------+
#
# +-------+----------------------+
# |summary|BroadcastOriginPointID|
# +-------+----------------------+
# |  count|                  9978|
# |   mean|    2.1390058127881337|
# | stddev|    0.9323192037553322|
# |    min|                     1|
# |    max|                     3|
# +-------+----------------------+
#
# +-------+------------------+
# |summary|     CompositionID|
# +-------+------------------+
# |  count|              9978|
# |   mean|3.4141110442974543|
# | stddev|0.9338603403654625|
# |    min|                 1|
# |    max|                 4|
# +-------+------------------+
#
# +-------+------------------+
# |summary|         Language1|
# +-------+------------------+
# |  count|             12586|
# |   mean|101.75377403464167|
# | stddev| 45.68403685468215|
# |    min|                94|
# |    max|               437|
# +-------+------------------+
#
# +-------+------------------+
# |summary|         Language2|
# +-------+------------------+
# |  count|              2629|
# |   mean|175.49334347660707|
# | stddev|  86.0360379288395|
# |    min|                 3|
# |    max|               438|
# +-------+------------------+

# %% [markdown]
# ## In class exercise

# %% [markdown]
# ### 1. Create a new data frame, logs_clean, that contains only the columns that do not end with ID.

# %%
import os

directory=data_path+'/broadcast_logs/'

logs=spark.read.csv(os.path.join(directory, "BroadcastLogs_2018_Q3_M8_sample.CSV"),
                                 sep="|",
                                 header=True,
                                 inferSchema=True,
                                 timestampFormat="yyyy-MM-dd",)
logs.columns
# Out:
# ['BroadcastLogID',
#  'LogServiceID',
#  'LogDate',
#  'SequenceNO',
#  'AudienceTargetAgeID',
#  'AudienceTargetEthnicID',
#  'CategoryID',
#  'ClosedCaptionID',
#  'CountryOfOriginID',
#  'DubDramaCreditID',
#  'EthnicProgramID',
#  'ProductionSourceID',
#  'ProgramClassID',
#  'FilmClassificationID',
#  'ExhibitionID',
#  'Duration',
#  'EndTime',
#  'LogEntryDate',
#  'ProductionNO',
#  'ProgramTitle',
#  'StartTime',
#  'Subtitle',
#  'NetworkAffiliationID',
#  'SpecialAttentionID',
#  'BroadcastOriginPointID',
#  'CompositionID',
#  'Producer1',
#  'Producer2',
#  'Language1',
#  'Language2']

# %%
selected_columns=[column for column in logs.columns if not column.endswith('ID')]

logs_clean=logs.select(selected_columns)

logs_clean.columns
# Out:
# ['LogDate',
#  'SequenceNO',
#  'Duration',
#  'EndTime',
#  'LogEntryDate',
#  'ProductionNO',
#  'ProgramTitle',
#  'StartTime',
#  'Subtitle',
#  'Producer1',
#  'Producer2',
#  'Language1',
#  'Language2']

# %% [markdown]
# ### 2. Display a list of program title that includes word apple, remove duplidate.

# %%
logs.filter(F.lower(F.col('ProgramTitle')).contains('apple')).select('ProgramTitle').distinct().show(5, False)
# Out:
# +-------------------------------+
# |ProgramTitle                   |
# +-------------------------------+
# |Apple Canada                   |
# |Apple Canada Inc.              |
# |1-APPLE CDA INC-Electronics 3rd|
# |APPLE / IRO / MEMORY ROGERS    |
# |APPLE / IBE / MEMORY BELL      |
# +-------------------------------+
# only showing top 5 rows

# %% [markdown]
# ### 3. Display top 5 program title based on number of times it has been broadcasted.

# %%
logs.groupBy('ProgramTitle').count().orderBy(F.desc('count')).show(5, False)
# Out:
# +------------------------------------------+-----+
# |ProgramTitle                              |count|
# +------------------------------------------+-----+
# |15-SPECIALTY CHANNELS-Promotions Specialty|4453 |
# |15-SPECIALTY CHANNELS-Canadian Generic    |2410 |
# |15-GLOBAL TV TORONTO-Promotions Global    |1931 |
# |Station Identification                    |1004 |
# |PROCTER & GAMBLE INC.-                    |897  |
# +------------------------------------------+-----+
# only showing top 5 rows
